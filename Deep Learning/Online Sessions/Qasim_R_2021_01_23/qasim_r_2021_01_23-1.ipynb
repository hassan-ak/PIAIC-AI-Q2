# %% [markdown]
# # Deep Learning - Muhammad Qasim - 2021/01/23

# %% [markdown]
# # Marks Sheet Grading Example for AI, ML and DL

# %% [markdown]
# ## Classification

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(np.random.randint(20,32, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df2 = pd.DataFrame(np.random.randint(33,39, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df3 = pd.DataFrame(np.random.randint(0,49, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df4 = pd.DataFrame(np.random.randint(50,59, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df5 = pd.DataFrame(np.random.randint(60,69, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df6 = pd.DataFrame(np.random.randint(70,79, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df7 = pd.DataFrame(np.random.randint(80,100, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])


df = pd.concat([df1,df2,df3,df4,df5,df6,df7])

# No need of such data as it is already concatinated
del df1,df2,df3,df4,df5,df6,df7


df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  27  23  20  23  20
# 1  28  28  21  22  25
# 2  29  27  27  31  21
# 3  21  21  25  20  27
# 4  26  23  26  20  23

# %%
df['obtained'] = df.s1 + df.s2 + df.s3 + df.s4 + df.s5
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained
# 0  27  23  20  23  20       113
# 1  28  28  21  22  25       124
# 2  29  27  27  31  21       135
# 3  21  21  25  20  27       114
# 4  26  23  26  20  23       118

# %%
df['obtained'] = df.loc[:,:].sum(axis=1)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained
# 0  27  23  20  23  20       226
# 1  28  28  21  22  25       248
# 2  29  27  27  31  21       270
# 3  21  21  25  20  27       228
# 4  26  23  26  20  23       236

# %%
df['percentage'] = df.obtained / 500 * 100
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage
# 0  27  23  20  23  20       226        45.2
# 1  28  28  21  22  25       248        49.6
# 2  29  27  27  31  21       270        54.0
# 3  21  21  25  20  27       228        45.6
# 4  26  23  26  20  23       236        47.2

# %% [markdown]
# # apply Symbolic AI, Classicial programming, tranditional programming, Rules Based programmin
# - Rules always define by programmer

# %% [markdown]
# - Rules + Input = Output

# %%
def grade(x):
    if x >= 85:
        return "A+"
    elif x >= 70:
        return "A"
    elif x >= 60:
        return "B"
    elif x >= 50:
        return "C"
    elif x >= 40:
        return "D"
    elif x >= 33:
        return "E"
    else:
        return "F"
    
df['Grade'] = df.percentage.apply(grade)
df
# Out:
#       s1  s2  s3  s4  s5  obtained  percentage Grade
# 0     27  23  20  23  20       226        45.2     D
# 1     28  28  21  22  25       248        49.6     D
# 2     29  27  27  31  21       270        54.0     C
# 3     21  21  25  20  27       228        45.6     D
# 4     26  23  26  20  23       236        47.2     D
# ...   ..  ..  ..  ..  ..       ...         ...   ...
# 4995  95  92  89  84  95       910       182.0    A+
# 4996  93  84  91  82  94       888       177.6    A+
# 4997  90  95  82  96  96       918       183.6    A+
# 4998  99  84  94  94  88       918       183.6    A+
# 4999  93  80  85  91  83       864       172.8    A+
#
# [35000 rows x 8 columns]

# %%
df.shape
# Out:
# (35000, 8)

# %%
df.Grade.value_counts()
# Out:
# A+    20004
# C      4510
# A      4130
# D      3213
# B      1845
# E       691
# F       607
# Name: Grade, dtype: int64

# %%
df.corr().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dic = {
    'F':7,
    "E":6,
    "D":5,
    "C":4,
    "B":3,
    "A":2,
    "A+":1
}
df['Grade1'] = df.Grade.map(dic)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade  Grade1
# 0  27  23  20  23  20       226        45.2     D       5
# 1  28  28  21  22  25       248        49.6     D       5
# 2  29  27  27  31  21       270        54.0     C       4
# 3  21  21  25  20  27       228        45.6     D       5
# 4  26  23  26  20  23       236        47.2     D       5

# %%
df.corr().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dic = {
    'F':1,
    "E":2,
    "D":3,
    "C":4,
    "B":5,
    "A":6,
    "A+":7
}
df['Grade1'] = df.Grade.map(dic)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade  Grade1
# 0  27  23  20  23  20       226        45.2     D       3
# 1  28  28  21  22  25       248        49.6     D       3
# 2  29  27  27  31  21       270        54.0     C       4
# 3  21  21  25  20  27       228        45.6     D       3
# 4  26  23  26  20  23       236        47.2     D       3

# %%
df.corr().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Find Grades(Rules) with Deep Learning
# - input + Output = Rules

# %%
df1 = df[['s1', 's2', 's3', 's4', 's5', 'Grade']]
df1.head(2)
# Out:
#    s1  s2  s3  s4  s5 Grade
# 0  27  23  20  23  20     D
# 1  28  28  21  22  25     D

# %%
df1 = df1.sample(frac=1)
df1
# Out:
#       s1  s2  s3  s4  s5 Grade
# 197   82  80  84  92  95    A+
# 702   34  33  38  34  37     A
# 2289  62  62  62  62  63    A+
# 2717  81  84  93  95  95    A+
# 2074  62  60  62  63  62    A+
# ...   ..  ..  ..  ..  ..   ...
# 516   85  91  87  98  85    A+
# 3362  97  96  94  86  88    A+
# 4547  21  26  20  27  20     D
# 3403  85  80  96  98  98    A+
# 410   29  31  28  23  29     C
#
# [35000 rows x 6 columns]

# %%
X = df1.loc[:, 's1':'s5']
X.head()
# Out:
#       s1  s2  s3  s4  s5
# 197   82  80  84  92  95
# 702   34  33  38  34  37
# 2289  62  62  62  62  63
# 2717  81  84  93  95  95
# 2074  62  60  62  63  62

# %%
Y = df1[['Grade']]
Y.head()
# Out:
#      Grade
# 197     A+
# 702      A
# 2289    A+
# 2717    A+
# 2074    A+

# %%
#   A     B     C      D 
#   .30   .20   .35    .15   = 1
#               OK

# %% [markdown]
# # Vectorization to Y
# - one-hot-encoding

# %%
#    A+ A B C D E F
# A+ 1  0 0 0 0 0 0
# A  0  1 0 0 0 0 0
# B  0  0 1 0 0 0 0
# C  0  0 0 1 0 0 0
# D  0  0 0 0 1 0 0
# E  0  0 0 0 0 1 0
# F  0  0 0 0 0 0 1

# D = 0000100
# A = 0100000

# %%
display(Y.head())
Y = pd.get_dummies(Y)
# Out:
#      Grade
# 197     A+
# 702      A
# 2289    A+
# 2717    A+
# 2074    A+

# %%
display(Y.head())
# Out:
#       Grade_A  Grade_A+  Grade_B  Grade_C  Grade_D  Grade_E  Grade_F
# 197         0         1        0        0        0        0        0
# 702         1         0        0        0        0        0        0
# 2289        0         1        0        0        0        0        0
# 2717        0         1        0        0        0        0        0
# 2074        0         1        0        0        0        0        0

# %%
#   s1 s2 s3 s4 s5       A   A+  B   C   D   E   F 
# [[98,56,79,90,50]] = [.3, .1, .20,.1, .1, .1, .1]

# %%
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35000 entries, 197 to 410
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Grade_A   35000 non-null  uint8
#  1   Grade_A+  35000 non-null  uint8
#  2   Grade_B   35000 non-null  uint8
#  3   Grade_C   35000 non-null  uint8
#  4   Grade_D   35000 non-null  uint8
#  5   Grade_E   35000 non-null  uint8
#  6   Grade_F   35000 non-null  uint8
# dtypes: uint8(7)
# memory usage: 512.7 KB

# %%
Y.drop_duplicates()
# Out:
#       Grade_A  Grade_A+  Grade_B  Grade_C  Grade_D  Grade_E  Grade_F
# 197         0         1        0        0        0        0        0
# 702         1         0        0        0        0        0        0
# 2358        0         0        0        0        1        0        0
# 3144        0         0        0        1        0        0        0
# 1749        0         0        1        0        0        0        0
# 447         0         0        0        0        0        0        1
# 1676        0         0        0        0        0        1        0

# %%
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35000 entries, 197 to 410
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Grade_A   35000 non-null  uint8
#  1   Grade_A+  35000 non-null  uint8
#  2   Grade_B   35000 non-null  uint8
#  3   Grade_C   35000 non-null  uint8
#  4   Grade_D   35000 non-null  uint8
#  5   Grade_E   35000 non-null  uint8
#  6   Grade_F   35000 non-null  uint8
# dtypes: uint8(7)
# memory usage: 512.7 KB

# %% [markdown]
# ##### import some fundamentals lib

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD
# Out:
# 2022-04-30 21:44:31.223654: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:31.223691: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# Create your model network structure
# - first-layer (input_shape = X.no_of_columns)
# - last-layers (output=Y.unique_labels(unique classes))
#     - activation = according to your problems (4.6)
# - Dense(output, )

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(5,)))
model.add(Dense(16, activation='relu', ))
model.add(Dense(7, activation='relu', ))
model.add(Dense(7, activation='softmax'))
# Out:
# 2022-04-30 21:44:32.878916: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-30 21:44:32.879377: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879444: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879509: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879572: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879634: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879697: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879758: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879819: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-04-30 21:44:32.879832: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                192
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 7)                 119
#
#  dense_3 (Dense)             (None, 7)                 56
#
# =================================================================
# Total params: 895
# Trainable params: 895
# Non-trainable params: 0
# _________________________________________________________________

# %%
# select loss function based on your problems

model.compile(optimizer=SGD(learning_rate=0.002),
             loss='categorical_crossentropy',
             metrics=['acc'])

# %%
model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 1094/1094 [==============================] - 2s 1ms/step - loss: 1.0563 - acc: 0.5940
# Epoch 2/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.8976 - acc: 0.6139
# Epoch 3/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.8493 - acc: 0.6355
# Epoch 4/100
# 1094/1094 [==============================] - 2s 1ms/step - loss: 0.8146 - acc: 0.6567
# Epoch 5/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.7883 - acc: 0.6722
# Epoch 6/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.7659 - acc: 0.6829
# Epoch 7/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.7456 - acc: 0.6883
# Epoch 8/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.7273 - acc: 0.6923
# Epoch 9/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.7114 - acc: 0.6935
# Epoch 10/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6956 - acc: 0.6970
# Epoch 11/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6809 - acc: 0.7007
# Epoch 12/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6679 - acc: 0.7081
# Epoch 13/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6544 - acc: 0.7183
# Epoch 14/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6410 - acc: 0.7299
# Epoch 15/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6311 - acc: 0.7399
# Epoch 16/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6197 - acc: 0.7501
# Epoch 17/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.6096 - acc: 0.7601
# Epoch 18/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5996 - acc: 0.7685
# Epoch 19/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5886 - acc: 0.7770
# Epoch 20/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5819 - acc: 0.7832
# Epoch 21/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5717 - acc: 0.7930
# Epoch 22/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5628 - acc: 0.7964
# Epoch 23/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5537 - acc: 0.8019
# Epoch 24/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5494 - acc: 0.8038
# Epoch 25/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5440 - acc: 0.8086
# Epoch 26/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5343 - acc: 0.8132
# Epoch 27/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5250 - acc: 0.8160
# Epoch 28/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5211 - acc: 0.8151
# Epoch 29/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5133 - acc: 0.8167
# Epoch 30/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5059 - acc: 0.8183
# Epoch 31/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.5000 - acc: 0.8187
# Epoch 32/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4957 - acc: 0.8203
# Epoch 33/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4902 - acc: 0.8213
# Epoch 34/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4863 - acc: 0.8229
# Epoch 35/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4769 - acc: 0.8254
# Epoch 36/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4746 - acc: 0.8253
# Epoch 37/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4683 - acc: 0.8257
# Epoch 38/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4662 - acc: 0.8250
# Epoch 39/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4647 - acc: 0.8261
# Epoch 40/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4611 - acc: 0.8261
# Epoch 41/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4655 - acc: 0.8257
# Epoch 42/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4505 - acc: 0.8283
# Epoch 43/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4474 - acc: 0.8284
# Epoch 44/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4423 - acc: 0.8300
# Epoch 45/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4411 - acc: 0.8295
# Epoch 46/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4395 - acc: 0.8296
# Epoch 47/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4423 - acc: 0.8295
# Epoch 48/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4398 - acc: 0.8295
# Epoch 49/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4296 - acc: 0.8323
# Epoch 50/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4285 - acc: 0.8323
# Epoch 51/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4316 - acc: 0.8311
# Epoch 52/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4212 - acc: 0.8339
# Epoch 53/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4213 - acc: 0.8337
# Epoch 54/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4255 - acc: 0.8323
# Epoch 55/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4137 - acc: 0.8354
# Epoch 56/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4148 - acc: 0.8373
# Epoch 57/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4146 - acc: 0.8377
# Epoch 58/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.4012 - acc: 0.8408
# Epoch 59/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3981 - acc: 0.8417
# Epoch 60/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3972 - acc: 0.8440
# Epoch 61/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3916 - acc: 0.8461
# Epoch 62/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3971 - acc: 0.8456
# Epoch 63/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3767 - acc: 0.8522
# Epoch 64/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3710 - acc: 0.8577
# Epoch 65/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3671 - acc: 0.8575
# Epoch 66/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3624 - acc: 0.8596
# Epoch 67/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3529 - acc: 0.8625
# Epoch 68/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3452 - acc: 0.8651
# Epoch 69/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3409 - acc: 0.8677
# Epoch 70/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3401 - acc: 0.8687
# Epoch 71/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3338 - acc: 0.8726
# Epoch 72/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3295 - acc: 0.8725
# Epoch 73/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3240 - acc: 0.8765
# Epoch 74/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3230 - acc: 0.8753
# Epoch 75/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3178 - acc: 0.8783
# Epoch 76/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3135 - acc: 0.8805
# Epoch 77/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3115 - acc: 0.8815
# Epoch 78/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3063 - acc: 0.8839
# Epoch 79/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3031 - acc: 0.8856
# Epoch 80/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.3005 - acc: 0.8869
# Epoch 81/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2975 - acc: 0.8889
# Epoch 82/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2951 - acc: 0.8894
# Epoch 83/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2914 - acc: 0.8915
# Epoch 84/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2898 - acc: 0.8910
# Epoch 85/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2854 - acc: 0.8933
# Epoch 86/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2825 - acc: 0.8954
# Epoch 87/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2787 - acc: 0.8968
# Epoch 88/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2768 - acc: 0.8961
# Epoch 89/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2750 - acc: 0.8971
# Epoch 90/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2732 - acc: 0.8983
# Epoch 91/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2706 - acc: 0.8991
# Epoch 92/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2695 - acc: 0.8988
# Epoch 93/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2666 - acc: 0.9013
# Epoch 94/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2626 - acc: 0.9011
# Epoch 95/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2615 - acc: 0.9013
# Epoch 96/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2587 - acc: 0.9037
# Epoch 97/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2587 - acc: 0.9033
# Epoch 98/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2589 - acc: 0.9008
# Epoch 99/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2546 - acc: 0.9042
# Epoch 100/100
# 1094/1094 [==============================] - 1s 1ms/step - loss: 0.2525 - acc: 0.9042

# %%
df1 = pd.DataFrame(np.random.randint(20,100, size=(20,5)),
                  columns = ['s1','s2','s3','s4','s5'])

df1
# Out:
#     s1  s2  s3  s4  s5
# 0   36  69  83  66  89
# 1   45  75  72  82  27
# 2   86  29  26  28  35
# 3   58  75  38  67  76
# 4   60  85  28  34  77
# 5   85  80  57  53  61
# 6   80  84  45  21  76
# 7   49  21  78  40  96
# 8   73  53  47  78  64
# 9   40  73  97  56  24
# 10  66  36  92  23  20
# 11  48  97  84  66  58
# 12  59  81  92  48  28
# 13  90  65  64  93  87
# 14  66  72  78  24  68
# 15  37  86  66  73  58
# 16  60  96  84  46  82
# 17  63  78  61  24  51
# 18  96  49  29  81  57
# 19  46  24  35  40  23

# %%
Y.columns.take(np.argmax(model.predict([[90,98,95,97,95]]), axis=1))
# Out:
# Index(['Grade_A+'], dtype='object')

# %%
df1['predict']=Y.columns.take(np.argmax(model.predict(df1.loc[:,'s1':'s5']), axis=1))
df1
# Out:
#     s1  s2  s3  s4  s5   predict
# 0   36  69  83  66  89  Grade_A+
# 1   45  75  72  82  27  Grade_A+
# 2   86  29  26  28  35  Grade_A+
# 3   58  75  38  67  76  Grade_A+
# 4   60  85  28  34  77  Grade_A+
# 5   85  80  57  53  61  Grade_A+
# 6   80  84  45  21  76  Grade_A+
# 7   49  21  78  40  96  Grade_A+
# 8   73  53  47  78  64  Grade_A+
# 9   40  73  97  56  24  Grade_A+
# 10  66  36  92  23  20  Grade_A+
# 11  48  97  84  66  58  Grade_A+
# 12  59  81  92  48  28  Grade_A+
# 13  90  65  64  93  87  Grade_A+
# 14  66  72  78  24  68  Grade_A+
# 15  37  86  66  73  58  Grade_A+
# 16  60  96  84  46  82  Grade_A+
# 17  63  78  61  24  51  Grade_A+
# 18  96  49  29  81  57  Grade_A+
# 19  46  24  35  40  23   Grade_A

# %%
model.save("gradeModel.hd5")
# Out:
# 2022-04-30 21:46:54.345948: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: gradeModel.hd5/assets

# %% [markdown]
# # Find Grades(Rules) With Machine Learning

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
#split dataset in features and target variable
feature_cols = ['percentage']
X = df[feature_cols] # Features
y = df.Grade # Target variable

# %%
X.head(1)
# Out:
#    percentage
# 0        45.2

# %%
y.head(1)
# Out:
# 0    D
# Name: Grade, dtype: object

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# %%
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

# %%
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled=tree, class_names=True,
              fontsize=8)
# Out:
# [Text(0.7777777777777778, 0.9166666666666666, 'X[0] <= 85.0\ngini = 0.629\nsamples = 24500\nvalue = [2891, 14052, 1313, 3117, 2204, 500, 423]\nclass = y[1]'),
#  Text(0.6666666666666666, 0.75, 'X[0] <= 69.8\ngini = 0.77\nsamples = 10448\nvalue = [2891, 0, 1313, 3117, 2204, 500, 423]\nclass = y[3]'),
#  Text(0.5555555555555556, 0.5833333333333334, 'X[0] <= 49.8\ngini = 0.707\nsamples = 7557\nvalue = [0, 0, 1313, 3117, 2204, 500, 423]\nclass = y[3]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'X[0] <= 39.8\ngini = 0.459\nsamples = 3127\nvalue = [0, 0, 0, 0, 2204, 500, 423]\nclass = y[4]'),
#  Text(0.2222222222222222, 0.25, 'X[0] <= 33.0\ngini = 0.497\nsamples = 923\nvalue = [0, 0, 0, 0, 0, 500, 423]\nclass = y[5]'),
#  Text(0.1111111111111111, 0.08333333333333333, 'gini = 0.0\nsamples = 423\nvalue = [0, 0, 0, 0, 0, 0, 423]\nclass = y[6]'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 500\nvalue = [0, 0, 0, 0, 0, 500, 0]\nclass = y[5]'),
#  Text(0.4444444444444444, 0.25, 'gini = 0.0\nsamples = 2204\nvalue = [0, 0, 0, 0, 2204, 0, 0]\nclass = y[4]'),
#  Text(0.7777777777777778, 0.4166666666666667, 'X[0] <= 59.8\ngini = 0.417\nsamples = 4430\nvalue = [0, 0, 1313, 3117, 0, 0, 0]\nclass = y[3]'),
#  Text(0.6666666666666666, 0.25, 'gini = 0.0\nsamples = 3117\nvalue = [0, 0, 0, 3117, 0, 0, 0]\nclass = y[3]'),
#  Text(0.8888888888888888, 0.25, 'gini = 0.0\nsamples = 1313\nvalue = [0, 0, 1313, 0, 0, 0, 0]\nclass = y[2]'),
#  Text(0.7777777777777778, 0.5833333333333334, 'gini = 0.0\nsamples = 2891\nvalue = [2891, 0, 0, 0, 0, 0, 0]\nclass = y[0]'),
#  Text(0.8888888888888888, 0.75, 'gini = 0.0\nsamples = 14052\nvalue = [0, 14052, 0, 0, 0, 0, 0]\nclass = y[1]')]
