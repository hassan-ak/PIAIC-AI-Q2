# %% [markdown]
# # Data Loading, Storage, and File Formats

# %% [markdown]
# ## 6.3 Interacting with Web APIs

# %%
import requests
import pandas as pd
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39862',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39862/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39862/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39862/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39862',
#   'id': 810041253,
#   'node_id': 'MDU6SXNzdWU4MTAwNDEyNTM=',
#   'number': 39862,
#   'title': 'BUG: Docs website is blocked by google safe browsing',
#   'user': {'login': 'nylocx',
#    'id': 3329124,
#    'node_id': 'MDQ6VXNlcjMzMjkxMjQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3329124?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nylocx',
#    'html_url': 'https://github.com/nylocx',
#    'followers_url': 'https://api.github.com/users/nylocx/followers',
#    'following_url': 'https://api.github.com/users/nylocx/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/nylocx/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/nylocx/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/nylocx/subscriptions',
#    'organizations_url': 'https://api.github.com/users/nylocx/orgs',
#    'repos_url': 'https://api.github.com/users/nylocx/repos',
#    'events_url': 'https://api.github.com/users/nylocx/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/nylocx/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-02-17T10:10:15Z',
#   'updated_at': '2021-02-17T12:33:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "I hope it's ok to skip the template as this is not a direct code bug but a website bug.\r\nSorry for the german locales, but I guess the message is pretty clear anyways. The pandas docs are blocked by google safe browsing service.\r\n\r\n![image](https://user-images.githubusercontent.com/3329124/108188866-64d49180-7110-11eb-8b42-b67adddd4db3.png)\r\n\r\nHope this can be clarified quickly as there will be a a lot of support lines in companies running hot ;).",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39861',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39861/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39861/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39861/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39861',
#   'id': 809996244,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTc0NzU5MjI0',
#   'number': 39861,
#   'title': '[POC] PERF: 1d version of the cython grouped aggregation algorithms',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-02-17T09:10:05Z',
#   'updated_at': '2021-02-17T12:34:01Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39861',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39861',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39861.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39861.patch'},
#   'body': 'For now, this is just a small example to open discussion about how to tackle this topic (not meant for merging).\r\n\r\nContext: for a columnar dataframe (with ArrayManager), we would also perform the groupby operations column by column (instead of on the 2D blocks). Most of our custom cython aggregation algorithms are currently written for 2D arrays (eg `group_add`, `group_mean`, etc. I think only the fill/shift/any/all are 1D). But by being 2D, that means they have some performance penalty when using it for a single column.\r\n\r\nExperiment: I copied the implementation for "mean" and made a 1D version of it (exactly the same code, but removing one `for` loop over the columns, and simplifying the indices to index into 1D arrays instead of 2D arrays). \r\nAnd with that did some timings to see the impact:\r\n\r\n```python\r\nN = 1_000_000\r\ndf = pd.DataFrame(np.random.randn(N, 10), columns=list("abcdefghij"))\r\ndf["key"] = np.random.randint(0, 100, size=N)\r\n\r\n# below I am manually doing the aggregation part for one column of the following groupby operation\r\nexpected = df.groupby("key").mean()\r\n```\r\n\r\nUsing the existing 2D algorithm on a single column:\r\n\r\n```python\r\ncodes, uniques = pd.factorize(df["key"], sort=True)\r\nout_shape = (len(uniques), 1)\r\nout_dtype = "float64"\r\n\r\nvalues = df[[\'a\']]._mgr.blocks[0].values.T\r\n\r\nresult = np.empty(out_shape, out_dtype)\r\nresult.fill(np.nan)\r\ncounts = np.zeros(len(uniques), dtype=np.int64)\r\n\r\npd._libs.groupby.group_mean_float64(result, counts, values, codes, min_count=-1)\r\n```\r\n\r\nUsing the new 1D version:\r\n\r\n```python\r\nout_shape1d = (len(uniques),)\r\nout_dtype = "float64"\r\n\r\nvalues1d = df[\'a\']._mgr.blocks[0].values.copy()\r\n\r\nresult1d = np.empty(out_shape1d, out_dtype)\r\nresult1d.fill(np.nan)\r\ncounts = np.zeros(len(uniques), dtype=np.int64)\r\n\r\npd._libs.groupby.group_mean_1d_float64(result1d, counts, values1d, codes, min_count=-1)\r\n```\r\n\r\nEnsure that both give the same result:\r\n\r\n```\r\nIn [4]: np.allclose(result.squeeze(), expected[\'a\'].values)\r\nOut[4]: True\r\n\r\nIn [5]: np.allclose(result1d, expected[\'a\'].values)\r\nOut[5]: True\r\n```\r\n\r\nAnd timings for both:\r\n\r\n```\r\nIn [8]: %%timeit\r\n   ...: result = np.empty(out_shape, out_dtype)\r\n   ...: result.fill(np.nan)\r\n   ...: counts = np.zeros(len(uniques), dtype=np.int64)\r\n   ...: pd._libs.groupby.group_mean_float64(result, counts, values, codes, min_count=-1)\r\n\r\n4.15 ms ± 54.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)\r\n\r\nIn [9]: %%timeit\r\n   ...: result1d = np.empty(out_shape1d, out_dtype)\r\n   ...: result1d.fill(np.nan)\r\n   ...: counts = np.zeros(len(uniques), dtype=np.int64)\r\n   ...: pd._libs.groupby.group_mean_1d_float64(result1d, counts, values1d, codes, min_count=-1)\r\n\r\n2.62 ms ± 38.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)\r\n```\r\n\r\nSo for a single column, the 1D version is ca 30-40% faster (increasing the size of the array with 10x, I also get 40% faster).\r\n\r\nSome notes:\r\n\r\n- The actual aggregation is only a part of the full groupby operation. But for sufficiently large data, it becomes the most significant portion. E.g. for the `df.groupby("key").mean()` example above, the `group_mean` takes ca 1.5x the time of the factorization step (that\'s for multiple columns, though, when profiling it for grouping a single column, the ratio becomes the other way around: ca 38% in group_mean and ca 62% in factorization)\r\n- If we want to have an optimized groupby for the ArrayManager-backed dataframe, I think we will need those 1D versions of the cython algos. Of course, what I currently did here would give a huge duplication in code (and also not easily templateable or so) on the short term.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39860',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39860/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39860/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39860/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39860',
#   'id': 809985742,
#   'node_id': 'MDU6SXNzdWU4MDk5ODU3NDI=',
#   'number': 39860,
#   'title': "BUG: read_json() converts non-existent fields in text 'NaN'",
#   'user': {'login': 'Rutrus',
#    'id': 4362131,
#    'node_id': 'MDQ6VXNlcjQzNjIxMzE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4362131?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rutrus',
#    'html_url': 'https://github.com/Rutrus',
#    'followers_url': 'https://api.github.com/users/Rutrus/followers',
#    'following_url': 'https://api.github.com/users/Rutrus/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Rutrus/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Rutrus/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Rutrus/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Rutrus/orgs',
#    'repos_url': 'https://api.github.com/users/Rutrus/repos',
#    'events_url': 'https://api.github.com/users/Rutrus/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Rutrus/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-02-17T08:55:04Z',
#   'updated_at': '2021-02-17T08:59:52Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n\r\nI am reading a big JSON file with json in lines:\r\n`pandas.read_json("big_file.json", chunksize=20, lines=True)`\r\n\r\n- There are some extra keys in some lines, so non-existent keys are converted to NaN.\r\n- Dtype is object\r\n- I discovered it when I was trying to save into database because it fails to convert \'NaN\' to JSON_ARRAY()\r\n- `dataframe.fillna(\'value\')` is not working with that value\r\n- NaN is considered non-null (text)\r\n\r\n```\r\nRangeIndex: 20 entries, 40 to 59\r\nData columns (total 6 columns):\r\n #   Column    Non-Null Count  Dtype \r\n---  ------    --------------  ----- \r\n 0   t_list    20 non-null     object\r\n...\r\n```\r\n\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 7d32926db8f7541c356066dcadabf854487738de\r\npython           : 3.8.5.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-65-generic\r\nVersion          : #73-Ubuntu SMP Mon Jan 18 17:25:17 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.2\r\nnumpy            : 1.20.1\r\npytz             : 2021.1\r\ndateutil         : 2.7.3\r\npip              : 21.0.1\r\nsetuptools       : 45.2.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : 1.0.2\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.20.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : 1.3.23\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n```\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39859',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39859/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39859/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39859/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39859',
#   'id': 809889961,
#   'node_id': 'MDU6SXNzdWU4MDk4ODk5NjE=',
#   'number': 39859,
#   'title': 'DOC: add button to edit on GitHub',
#   'user': {'login': 'afeld',
#    'id': 86842,
#    'node_id': 'MDQ6VXNlcjg2ODQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86842?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/afeld',
#    'html_url': 'https://github.com/afeld',
#    'followers_url': 'https://api.github.com/users/afeld/followers',
#    'following_url': 'https://api.github.com/users/afeld/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/afeld/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/afeld/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/afeld/subscriptions',
#    'organizations_url': 'https://api.github.com/users/afeld/orgs',
#    'repos_url': 'https://api.github.com/users/afeld/repos',
#    'events_url': 'https://api.github.com/users/afeld/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/afeld/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-02-17T06:13:54Z',
#   'updated_at': '2021-02-17T08:25:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '#### Location of the documentation\r\n\r\nhttps://pandas.pydata.org/docs/\r\n\r\n#### Documentation problem\r\n\r\nI\'ll write it as a user story:\r\n\r\n_As a pandas user, when I come across a small problem with the documentation (like a typo), I want to be able to suggest a fix with minimal friction._\r\n\r\nCurrently, contributors need to search the repository to find the corresponding source file.\r\n\r\n#### Suggested fix for documentation\r\n\r\nHaving an "Edit this page on GitHub" button would help people contribute to documentation quickly. A couple of resources explaining how to do this with Sphinx:\r\n\r\n- https://mg.pov.lt/blog/sphinx-edit-on-github.html\r\n- https://gist.github.com/mgedmin/6052926\r\n\r\nCould limit to non-API pages to keep things simple. Possible it makes more sense to do this in [the theme](https://github.com/pydata/pydata-sphinx-theme).',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39858',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39858/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39858/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39858/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39858',
#   'id': 809873299,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTc0NjU5MTk4',
#   'number': 39858,
#   'title': 'Update matplotlib canonical',
#   'user': {'login': 'jklymak',
#    'id': 1562854,
#    'node_id': 'MDQ6VXNlcjE1NjI4NTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1562854?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jklymak',
#    'html_url': 'https://github.com/jklymak',
#    'followers_url': 'https://api.github.com/users/jklymak/followers',
#    'following_url': 'https://api.github.com/users/jklymak/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jklymak/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jklymak/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jklymak/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jklymak/orgs',
#    'repos_url': 'https://api.github.com/users/jklymak/repos',
#    'events_url': 'https://api.github.com/users/jklymak/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jklymak/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 112,
#    'closed_issues': 822,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-02-17T09:37:19Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-02-17T05:41:48Z',
#   'updated_at': '2021-02-17T08:10:12Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39858',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39858',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39858.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39858.patch'},
#   'body': 'Please see https://discourse.matplotlib.org/t/canonical-documentation-have-moved/21863\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39857',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39857/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39857/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39857/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39857',
#   'id': 809862249,
#   'node_id': 'MDU6SXNzdWU4MDk4NjIyNDk=',
#   'number': 39857,
#   'title': 'BUG: read_csv() does not read all the lines in a tsv file',
#   'user': {'login': 'vincent6liu',
#    'id': 17016778,
#    'node_id': 'MDQ6VXNlcjE3MDE2Nzc4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17016778?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vincent6liu',
#    'html_url': 'https://github.com/vincent6liu',
#    'followers_url': 'https://api.github.com/users/vincent6liu/followers',
#    'following_url': 'https://api.github.com/users/vincent6liu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vincent6liu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vincent6liu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vincent6liu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vincent6liu/orgs',
#    'repos_url': 'https://api.github.com/users/vincent6liu/repos',
#    'events_url': 'https://api.github.com/users/vincent6liu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vincent6liu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-02-17T05:17:30Z',
#   'updated_at': '2021-02-17T05:18:37Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "**Code Sample, a copy-pastable example if possible**\r\n`snps_df = pd.read_csv('cast_chr7_snps.txt', sep='\\t', header=None)`\r\n\r\n[cast_chr7_snps.txt](https://github.com/pandas-dev/pandas/files/5993376/cast_chr7_snps.txt)\r\n\r\n**Problem description**\r\n`pd.read_csv` doesn't read the entire file (30219/30423 rows).\r\nI double-checked and don't think there are empty lines in the file. Setting `skip_blank_lines=True` doesn't change the result.\r\n\r\nOutput of `pd.show_versions()`\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 9d598a5e1eee26df95b3910e3f2934890d062caa\r\npython           : 3.8.3.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.3.0\r\nVersion          : Darwin Kernel Version 20.3.0: Thu Jan 21 00:07:06 PST 2021; root:xnu-7195.81.3~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.1\r\nnumpy            : 1.19.1\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : None\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.17.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.4\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.5\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.0\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nxlwt             : None\r\nnumba            : None\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39856',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39856/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39856/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39856/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39856',
#   'id': 809829080,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTc0NjIyNTY1',
#   'number': 39856,
#   'title': 'CLN: assorted cleanups',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-02-17T03:51:45Z',
#   'updated_at': '2021-02-17T12:13:23Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39856',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39856',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39856.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39856.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39854',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39854/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39854/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39854/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39854',
#   'id': 809709990,
#   'node_id': 'MDU6SXNzdWU4MDk3MDk5OTA=',
#   'number': 39854,
#   'title': 'CI: 3.8 numpy_dev build failing recently',
#   'user': {'login': 'jreback',
#    'id': 953992,
#    'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jreback',
#    'html_url': 'https://github.com/jreback',
#    'followers_url': 'https://api.github.com/users/jreback/followers',
#    'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jreback/orgs',
#    'repos_url': 'https://api.github.com/users/jreback/repos',
#    'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jreback/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/83',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/83',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/83/labels',
#    'id': 6402340,
#    'node_id': 'MDk6TWlsZXN0b25lNjQwMjM0MA==',
#    'number': 83,
#    'title': '1.2.3',
#    'description': 'on-merge: backport to 1.2.x\r\n\r\n',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 17,
#    'closed_issues': 9,
#    'state': 'open',
#    'created_at': '2021-02-07T13:58:05Z',
#    'updated_at': '2021-02-16T22:58:37Z',
#    'due_on': '2021-03-01T08:00:00Z',
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2021-02-16T22:58:37Z',
#   'updated_at': '2021-02-16T23:44:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'https://dev.azure.com/pandas-dev/pandas/_build/results?buildId=54353&view=logs&j=eab14f69-13b6-5db7-daeb-7b778629410b&t=ce687173-08c6-5301-838d-71b2dda24510\r\n\r\n```\r\n2021-02-16T22:44:34.3078267Z =================================== FAILURES ===================================\r\n2021-02-16T22:44:34.3078772Z ___________________ TestTableOrientReader.test_comprehensive ___________________\r\n2021-02-16T22:44:34.3079881Z [gw1] linux -- Python 3.8.5 /home/vsts/miniconda3/envs/pandas-dev/bin/python\r\n2021-02-16T22:44:34.3080157Z \r\n2021-02-16T22:44:34.3080536Z self = <pandas.tests.io.json.test_json_table_schema.TestTableOrientReader object at 0x7f8908515790>\r\n2021-02-16T22:44:34.3080847Z \r\n2021-02-16T22:44:34.3081136Z     def test_comprehensive(self):\r\n2021-02-16T22:44:34.3081478Z         df = DataFrame(\r\n2021-02-16T22:44:34.3081758Z             {\r\n2021-02-16T22:44:34.3082075Z                 "A": [1, 2, 3, 4],\r\n2021-02-16T22:44:34.3082433Z                 "B": ["a", "b", "c", "c"],\r\n2021-02-16T22:44:34.3083091Z                 "C": pd.date_range("2016-01-01", freq="d", periods=4),\r\n2021-02-16T22:44:34.3083753Z                 # \'D\': pd.timedelta_range(\'1H\', periods=4, freq=\'T\'),\r\n2021-02-16T22:44:34.3084228Z                 "E": pd.Series(pd.Categorical(["a", "b", "c", "c"])),\r\n2021-02-16T22:44:34.3084712Z                 "F": pd.Series(pd.Categorical(["a", "b", "c", "c"], ordered=True)),\r\n2021-02-16T22:44:34.3085138Z                 "G": [1.1, 2.2, 3.3, 4.4],\r\n2021-02-16T22:44:34.3085802Z                 "H": pd.date_range("2016-01-01", freq="d", periods=4, tz="US/Central"),\r\n2021-02-16T22:44:34.3086267Z                 "I": [True, False, False, True],\r\n2021-02-16T22:44:34.3086608Z             },\r\n2021-02-16T22:44:34.3086937Z             index=pd.Index(range(4), name="idx"),\r\n2021-02-16T22:44:34.3087246Z         )\r\n2021-02-16T22:44:34.3087499Z     \r\n2021-02-16T22:44:34.3087786Z >       out = df.to_json(orient="table")\r\n2021-02-16T22:44:34.3087971Z \r\n2021-02-16T22:44:34.3088300Z pandas/tests/io/json/test_json_table_schema.py:772: \r\n2021-02-16T22:44:34.3088746Z _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\n2021-02-16T22:44:34.3089152Z pandas/core/generic.py:2499: in to_json\r\n2021-02-16T22:44:34.3089486Z     return json.to_json(\r\n2021-02-16T22:44:34.3090018Z pandas/io/json/_json.py:115: in to_json\r\n2021-02-16T22:44:34.3090343Z     s = writer(\r\n2021-02-16T22:44:34.3090703Z _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\n2021-02-16T22:44:34.3090961Z \r\n2021-02-16T22:44:34.3091280Z self = <pandas.io.json._json.JSONTableWriter object at 0x7f8908515f40>\r\n2021-02-16T22:44:34.3091597Z \r\n2021-02-16T22:44:34.3091857Z     def write(self):\r\n2021-02-16T22:44:34.3092200Z         iso_dates = self.date_format == "iso"\r\n2021-02-16T22:44:34.3092519Z >       return dumps(\r\n2021-02-16T22:44:34.3092827Z             self.obj_to_write,\r\n2021-02-16T22:44:34.3093139Z             orient=self.orient,\r\n2021-02-16T22:44:34.3093492Z             double_precision=self.double_precision,\r\n2021-02-16T22:44:34.3093853Z             ensure_ascii=self.ensure_ascii,\r\n2021-02-16T22:44:34.3094287Z             date_unit=self.date_unit,\r\n2021-02-16T22:44:34.3094747Z             iso_dates=iso_dates,\r\n2021-02-16T22:44:34.3095093Z             default_handler=self.default_handler,\r\n2021-02-16T22:44:34.3095449Z             indent=self.indent,\r\n2021-02-16T22:44:34.3095724Z         )\r\n2021-02-16T22:44:34.3096244Z E       DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.\r\n2021-02-16T22:44:34.3096661Z \r\n2021-02-16T22:44:34.3096974Z pandas/io/json/_json.py:177: DeprecationWarning\r\n\r\n```',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39853',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39853/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39853/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39853/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39853',
#   'id': 809706637,
#   'node_id': 'MDU6SXNzdWU4MDk3MDY2Mzc=',
#   'number': 39853,
#   'title': 'BUG: array ufuncs with more than 2 inputs fails with 2 or more pd.Series and scalar arguments',
#   'user': {'login': 'DocOtak',
#    'id': 868027,
#    'node_id': 'MDQ6VXNlcjg2ODAyNw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/868027?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DocOtak',
#    'html_url': 'https://github.com/DocOtak',
#    'followers_url': 'https://api.github.com/users/DocOtak/followers',
#    'following_url': 'https://api.github.com/users/DocOtak/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DocOtak/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DocOtak/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DocOtak/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DocOtak/orgs',
#    'repos_url': 'https://api.github.com/users/DocOtak/repos',
#    'events_url': 'https://api.github.com/users/DocOtak/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DocOtak/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-02-16T22:51:52Z',
#   'updated_at': '2021-02-16T22:51:52Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [x] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n(note that this requires the gsw library to be installed)\r\n\r\n```python\r\n>>> import gsw\r\n>>> import pandas as pd\r\n>>> gsw.SA_from_SP(pd.Series([30,30,30]), pd.Series([1000,1000,1000]), 0, 0)\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/Users/abarna/.pyenv/versions/gsw/lib/python3.8/site-packages/gsw/_utilities.py", line 62, in wrapper\r\n    ret = f(*newargs, **kw)\r\n  File "/Users/abarna/.pyenv/versions/gsw/lib/python3.8/site-packages/gsw/_wrapped_ufuncs.py", line 3245, in SA_from_SP\r\n    return _gsw_ufuncs.sa_from_sp(SP, p, lon, lat)\r\n  File "/Users/abarna/.pyenv/versions/gsw/lib/python3.8/site-packages/pandas/core/generic.py", line 1935, in __array_ufunc__\r\n    return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)\r\n  File "/Users/abarna/.pyenv/versions/gsw/lib/python3.8/site-packages/pandas/core/arraylike.py", line 284, in array_ufunc\r\n    raise NotImplementedError(\r\nNotImplementedError: Cannot apply ufunc <ufunc \'sa_from_sp\'> to mixed DataFrame and Series inputs.\r\n```\r\n\r\n#### Problem description\r\n\r\nMy group uses pandas with the [gsw](https://github.com/TEOS-10/GSW-Python) library to do some oceanographic calculations. gsw provides ufuncs to do these calculations. When more than one pd.Series is mixed with the scalar arguments at the end, it results in the NotImplementedError you see above. Also, gsw library itself was only recently updated to defer to the input\'s `__array_ufunc__` method if it is present.\r\n\r\n#### Expected Output\r\n\r\nThis is the result of some manual broadcasting:\r\n\r\n```python\r\n\r\n>>> gsw.SA_from_SP(pd.Series([30,30,30]), pd.Series([1000,1000,1000]), pd.Series([0, 0, 0]), pd.Series([0, 0, 0]))\r\n0    30.145599\r\n1    30.145599\r\n2    30.145599\r\ndtype: float64\r\n\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 7d32926db8f7541c356066dcadabf854487738de\r\npython           : 3.8.2.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.3.0\r\nVersion          : Darwin Kernel Version 20.3.0: Thu Jan 21 00:07:06 PST 2021; root:xnu-7195.81.3~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.2\r\nnumpy            : 1.20.1\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 19.2.3\r\nsetuptools       : 41.2.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39852',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39852/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39852/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39852/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39852',
#   'id': 809699755,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTc0NTE4MjQ5',
#   'number': 39852,
#   'title': 'PERF: is_list_like',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 112,
#    'closed_issues': 822,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-02-17T09:37:19Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2021-02-16T22:38:04Z',
#   'updated_at': '2021-02-17T08:18:23Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39852',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39852',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39852.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39852.patch'},
#   'body': '```\r\nIn [3]: arr = np.array(0)\r\nIn [4]: arr2 = np.array([0])\r\n\r\nIn [5]: %timeit is_list_like([])\r\n118 ns ± 2.21 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)   # <-- PR\r\n328 ns ± 3.3 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)   # <-- master\r\n\r\nIn [6]: %timeit is_list_like(0)\r\n271 ns ± 5.65 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)   # <-- PR\r\n348 ns ± 4.17 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)   # <-- master\r\n\r\nIn [7]: %timeit is_list_like(arr)\r\n111 ns ± 1.71 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)   # <-- PR\r\n369 ns ± 24.4 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)  # <-- master\r\n\r\nIn [8]: %timeit is_list_like(arr2)\r\n109 ns ± 3.39 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)   # <-- PR\r\n340 ns ± 1.91 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)  # <-- master\r\n\r\n```',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39850',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39850/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39850/comments',
# ...
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39820',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39820',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39820.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39820.patch'},
#   'body': "This is on top of https://github.com/pandas-dev/pandas/pull/39772, so only the last commit needs to be looked at for now: https://github.com/pandas-dev/pandas/pull/39820/commits/bd50388e019c61559c310638186aeea57d2d2d3e\r\n\r\nThe actual goal here is to have a version of [`array_ops.py::arithmetic_op`](https://github.com/pandas-dev/pandas/blob/9f792cd90373177bffa0e9f85a14d5d5b30fb289/pandas/core/ops/array_ops.py#L159-L191) that does *not* call `ensure_wrapped_if_datetimelike` on its arrays. Reason: when performing ops column-wise, this becomes unnecessary overhead, and so the goal is to ensure this on a higher level, before calling the `array_op`.\r\n\r\nSo the experiment in this PR is to actually remove `ensure_wrapped_if_datetimelike` from `arithmetic_op`, and then add it in the places that will call `arithmetic_op`, to see how much changes this needs. This would ensure that we can keep a single shared `arithmetic_op` for use by both ArrayManager and BlockManager. The alternative would be to make a variant of `arithmetic_op` without the `ensure_wrapped_if_datetimelike`. That would require fewer code changes, but would give some duplication around `arithmetic_op` content (but it's not that it is a long function). Thoughts on which approach to prefer?\r\n\r\ncc @jbrockmendel ",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39818',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39818/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39818/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39818/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39818',
#   'id': 808455892,
#   'node_id': 'MDU6SXNzdWU4MDg0NTU4OTI=',
#   'number': 39818,
#   'title': 'Object to String conversion Does not work in Panda',
#   'user': {'login': 'saniyaparveez',
#    'id': 42298656,
#    'node_id': 'MDQ6VXNlcjQyMjk4NjU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42298656?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saniyaparveez',
#    'html_url': 'https://github.com/saniyaparveez',
#    'followers_url': 'https://api.github.com/users/saniyaparveez/followers',
#    'following_url': 'https://api.github.com/users/saniyaparveez/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/saniyaparveez/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/saniyaparveez/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/saniyaparveez/subscriptions',
#    'organizations_url': 'https://api.github.com/users/saniyaparveez/orgs',
#    'repos_url': 'https://api.github.com/users/saniyaparveez/repos',
#    'events_url': 'https://api.github.com/users/saniyaparveez/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/saniyaparveez/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2365504893,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0ODkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Closing%20Candidate',
#     'name': 'Closing Candidate',
#     'color': 'be21f2',
#     'default': False,
#     'description': 'May be closeable, needs more eyeballs'},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-02-15T11:31:09Z',
#   'updated_at': '2021-02-15T16:15:12Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "I have a dataset consisting of 10,00,000 rows and one column has a data type of value eg. 'FY2020-Q1' and I am trying to convert this to a String Data type because I would like to apply a filter of == but it does not work when using with **astype.**\r\nBasically, the conversion does not work on a huge dataset but on a small dataset, it works.\r\n\r\n`df['fyq'] = df['fyq'].astype(str) and  also`\r\n\r\n`df['fyq'] = df['fyq'].astype('string')`\r\n\r\nI would like to filter like:  `df[df.fyq== 'FY2020-Q4']`\r\n\r\nPandas version in use is **1.2.2**\r\n\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39817',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39817/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39817/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39817/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39817',
#   'id': 808410263,
#   'node_id': 'MDU6SXNzdWU4MDg0MTAyNjM=',
#   'number': 39817,
#   'title': 'API: common dtype for bool + numeric: upcast to object or coerce to numeric? ',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1741841389,
#     'node_id': 'MDU6TGFiZWwxNzQxODQxMzg5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20-%20Consistency',
#     'name': 'API - Consistency',
#     'color': 'b60205',
#     'default': False,
#     'description': 'Internal Consistency of API/Behavior'},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 7,
#   'created_at': '2021-02-15T10:33:11Z',
#   'updated_at': '2021-02-16T20:18:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'We currently have an inconsistency in how we determine the common dtype for bool + numeric. \r\n\r\nNumpy coerces booleans to numeric values when combining with numeric dtype:\r\n\r\n```python\r\n>> np.concatenate([np.array([True]), np.array([1])])\r\narray([1, 1])\r\n```\r\n\r\nIn pandas, Series does the same:\r\n\r\n```python\r\n>>> pd.concat([pd.Series([True], dtype=bool), pd.Series([1.0], dtype=float)])\r\n0    1.0\r\n0    1.0\r\ndtype: float64\r\n```\r\n\r\nexcept if they are empty, then we ensure the result is object dtype:\r\n\r\n```python\r\n>>> pd.concat([pd.Series([], dtype=bool), pd.Series([], dtype=float)])\r\nSeries([], dtype: object)\r\n```\r\n\r\nAnd for DataFrame we return object dtype in all cases:\r\n\r\n```python\r\n>>> pd.concat([pd.DataFrame({\'a\': np.array([], dtype=bool)}), pd.DataFrame({\'a\': np.array([], dtype=float)})]).dtypes\r\na    object\r\ndtype: object\r\n>>> pd.concat([pd.DataFrame({\'a\': np.array([True], dtype=bool)}), pd.DataFrame({\'a\': np.array([1.0], dtype=float)})]).dtypes\r\na    object\r\ndtype: object\r\n```\r\n\r\nFor the nullable dtypes, we also have implemented this a bit inconsistently up to now:\r\n\r\n```python\r\n>>> pd.concat([pd.Series([True], dtype="boolean"), pd.Series([1], dtype="Int64")])\r\n0    1\r\n0    1\r\ndtype: Int64\r\n\r\n>>> pd.concat([pd.Series([True], dtype="boolean"), pd.Series([1], dtype="Float64")])\r\n0    True\r\n0     1.0\r\ndtype: object\r\n```\r\n\r\nSo here we preserve numeric dtype for Integer, but convert to object for Float. Now, the reason for this is because `IntegerDtype._get_common_dtype` handles the case of boolean dtype and then uses the numpy rules to determine the result dtype, while the FloatingDtype doesn\'t yet handle non-float dtypes and thus results in object dtype for anything else (also for float numpy dtype, which is obviously a bug / missing feature)\r\n\r\n---\r\n\r\nBasically we need to decide what the desired behaviour is for the bool + numeric dtype combination: coerce to numeric or upcast to object? (and then fix the inconsistencies according to the decided rule)\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39813',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39813/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39813/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39813/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39813',
#   'id': 808067349,
#   'node_id': 'MDU6SXNzdWU4MDgwNjczNDk=',
#   'number': 39813,
#   'title': 'ENH: Using pyright to analyze missing type declarations',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-02-14T23:00:29Z',
#   'updated_at': '2021-02-16T10:00:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'This describes a procedure for using the command line tool `pyright` (https://github.com/microsoft/pyright/blob/master/docs/command-line.md)  to identify places in the pandas code that are missing type declarations.  xref #28142 \r\n\r\n1. Install pyright:  See https://github.com/microsoft/pyright#command-line\r\n2. In your pandas development folder, create an empty file `py.typed` in the same folder as `pandas\\__init__.py`\r\n3. To get the complete analysis as a text file, in your shell, `cd` to the folder containing `README.md` from pandas, and type `pyright --verifytypes pandas! > pyright.out`\r\n4. To determine the modules that need the most work, use the script shown below named `verifytypes.py` which can be run from the command line as `python verifytypes.py` and will print the top 20 modules that need fixing.\r\n\r\nOpen issues for adding types:\r\n1. We will need to systematically bring over the typing work done by Microsoft in https://github.com/microsoft/python-type-stubs/tree/main/pandas to help enhance our type declarations.\r\n2. Using `pyright` to determine where thing are missing will not determine if we are missing appropriate overloads.  See example below.\r\n3. Most likely, the best way to test if we have all the overloads correct is by fully typing our `tests` code, and adding `# ignore` comments when we are specifically testing for incorrect types.\r\n\r\n<details>\r\n<summary>verifytypes.py utility</summary>\r\n\r\n```python\r\nimport subprocess\r\nimport json\r\nimport pandas as pd\r\n\r\n\r\ndef getpyrightout() -> bytes:\r\n    try:\r\n        pyrightout = subprocess.run(\r\n            ["pyright", "--outputjson", "--verifytypes", "pandas!"],\r\n            capture_output=True,\r\n            shell=True,\r\n        )\r\n    except Exception as e:\r\n        raise e\r\n\r\n    return pyrightout.stdout\r\n\r\n\r\ndef processjson(jsonstr: bytes):\r\n    d = json.loads(jsonstr)\r\n    msgsSeries = pd.Series([k["message"] for k in d["diagnostics"]])\r\n    msgsdf = msgsSeries.str.split(\'"\', n=2, expand=True)\r\n    msgsdf.columns = ["primary", "element", "extra"]\r\n    typemsgs = msgsdf[msgsdf.primary.str.startswith("Type")].copy()\r\n    typemsgs["module"] = typemsgs["element"].str.replace(r"\\.[A-Z][a-z_A-Z\\.]*$", "")\r\n    notest = typemsgs[~typemsgs.module.str.startswith("pandas.tests")]\r\n    print(\r\n        notest.groupby(["module", "primary"])\r\n        .size()\r\n        .sort_values(ascending=False)\r\n        .head(20)\r\n    )\r\n\r\n\r\nif __name__ == "__main__":\r\n    processjson(getpyrightout())\r\n```\r\n</details>\r\n\r\n<details>\r\n<summary>Example using DataFrame.rename() where overloads are needed</summary>\r\n\r\nThis is taken from https://github.com/microsoft/python-type-stubs/blob/main/pandas/core/frame.pyi\r\n\r\n```python\r\n    @overload\r\n    def fillna(\r\n        self,\r\n        value: Optional[Union[Scalar, Dict, Series, DataFrame]] = ...,\r\n        method: Optional[Literal["backfill", "bfill", "ffill", "pad"]] = ...,\r\n        axis: Optional[AxisType] = ...,\r\n        limit: int = ...,\r\n        downcast: Optional[Dict] = ...,\r\n        *,\r\n        inplace: Literal[True]\r\n    ) -> None: ...\r\n    @overload\r\n    def fillna(\r\n        self,\r\n        value: Optional[Union[Scalar, Dict, Series, DataFrame]] = ...,\r\n        method: Optional[Literal["backfill", "bfill", "ffill", "pad"]] = ...,\r\n        axis: Optional[AxisType] = ...,\r\n        limit: int = ...,\r\n        downcast: Optional[Dict] = ...,\r\n        *,\r\n        inplace: Literal[False] = ...\r\n    ) -> DataFrame: ...\r\n    @overload\r\n    def fillna(\r\n        self,\r\n        value: Optional[Union[Scalar, Dict, Series, DataFrame]] = ...,\r\n        method: Optional[Union[_str, Literal["backfill", "bfill", "ffill", "pad"]]] = ...,\r\n        axis: Optional[AxisType] = ...,\r\n        *,\r\n        limit: int = ...,\r\n        downcast: Optional[Dict] = ...,\r\n    ) -> Uni ...
#   'performed_via_github_app': None}]

# %%
data[0]['title']
# Out:
# 'BUG: Docs website is blocked by google safe browsing'

# %%
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    39862  BUG: Docs website is blocked by google safe br...
# 1    39861  [POC] PERF: 1d version of the cython grouped a...
# 2    39860  BUG: read_json() converts non-existent fields ...
# 3    39859                  DOC: add button to edit on GitHub
# 4    39858                        Update matplotlib canonical
# 5    39857  BUG: read_csv() does not read all the lines in...
# 6    39856                             CLN: assorted cleanups
# 7    39854           CI: 3.8 numpy_dev build failing recently
# 8    39853  BUG: array ufuncs with more than 2 inputs fail...
# 9    39852                                 PERF: is_list_like
# 10   39850  BUG: float formatters ignore "object" extensio...
# 11   39849  solved raise an error on redundant definition ...
# 12   39848  ASV: add frame ops benchmarks for varying n_ro...
# 13   39845  DOC: Reindexing behaviour of dataframe column-...
# 14   39844  CI: series_methods.IsInLongSeriesLookUpDominat...
# 15   39843  BUG: Creating empty datetime64[ns] column shou...
# 16   39841  [ArrayManager] Implement concat with axis=1 (m...
# 17   39839  BUG: When checking equality of column dtype - ...
# 18   39838  BUG: Problems round-tripping categoricals to/f...
# 19   39837  BUG: AttributeError: 'BlockManager' object has...
# 20   39836                       CI: remove stale assignments
# 21   39834           DEPS: change clipboard backend to pyclip
# 22   39833                         February 2021 Docs Meeting
# 23   39830      ENH: Hand numpy-like arrays with is_list_like
# 24   39823  Raise an error on redundant definition of sepa...
# 25   39821  [WIP] ENH: Styler builtins: `highlight_range` ...
# 26   39820  REF: call ensure_wrapped_if_datetimelike befor...
# 27   39818  Object to String conversion Does not work in P...
# 28   39817  API: common dtype for bool + numeric: upcast t...
# 29   39813  ENH: Using pyright to analyze missing type dec...
#
#                                                labels state
# 0   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1                                                  []  open
# 2   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 3   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 4   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 5                                                  []  open
# 6                                                  []  open
# 7   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 8   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 10  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 11  [{'id': 42670965, 'node_id': 'MDU6TGFiZWw0MjY3...  open
# 12  [{'id': 732775912, 'node_id': 'MDU6TGFiZWw3MzI...  open
# 13  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 14  [{'id': 732775912, 'node_id': 'MDU6TGFiZWw3MzI...  open
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 16  [{'id': 49094459, 'node_id': 'MDU6TGFiZWw0OTA5...  open
# 17  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 18  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 19  [{'id': 49379259, 'node_id': 'MDU6TGFiZWw0OTM3...  open
# 20  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 21  [{'id': 527603109, 'node_id': 'MDU6TGFiZWw1Mjc...  open
# 22  [{'id': 2187005593, 'node_id': 'MDU6TGFiZWwyMT...  open
# 23                                                 []  open
# 24  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 25  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 26  [{'id': 49094459, 'node_id': 'MDU6TGFiZWw0OTA5...  open
# 27  [{'id': 2365504893, 'node_id': 'MDU6TGFiZWwyMz...  open
# 28  [{'id': 1741841389, 'node_id': 'MDU6TGFiZWwxNz...  open
# 29  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
